# %%
import numpy as np
import pandas as pd
import janitor
import warnings
warnings.filterwarnings('ignore')
from datetime import datetime
import glob

# %%
bike_2019 = pd.read_csv("/Users/lee14257/Development/CMU/Perspectives_in Data_Science/Project/bike2019_transformed.csv")

# %% [markdown]
# ## Initial Check, drop NA rows for "capacity"

# %% [markdown]
# Since we will mainly be using the column "capacity" to set upper limits to the availability of a station, we must make sure to drop those stations with no information on capacity.

# %%
bike_2019.head()
# Out:
#    station_id         station_name                 date   bike_id  act  \
# 0       31000    STARTING BIKE NUM  2019-01-01 00:00:01  starting    5
# 1       31000  Eads St & 15th St S  2019-01-02 09:46:15    W23821   -1
# 2       31000  Eads St & 15th St S  2019-01-02 09:58:13    W21229   -1
# 3       31000  Eads St & 15th St S  2019-01-02 12:09:20    W23657    1
# 4       31000  Eads St & 15th St S  2019-01-02 12:12:59    W23657   -1
#
#    reshuffle  availability  capacity
# 0          0             5      15.0
# 1          0             4      15.0
# 2          0             3      15.0
# 3          0             4      15.0
# 4          0             3      15.0

# %%
len(bike_2019['station_id'].unique())
# Out:
# 581

# %%
# Drop rows that have NA values for "capacity"
bike_2019 = bike_2019.dropna()

# %%
# Make sure there are no more NA values
bike_2019[['capacity']].isnull().values.any()
# Out:
# False

# %% [markdown]
# ## Explore average availability in each station

# %% [markdown]
# We will be excluding all stations that had an average availability of -10 or lower, because this probably meant that there were additional large reshuffles going on behind the scenes that cannot be explained by the data. We will later use lower and upper limit to cap the availability of a station, because we are interested in the overall movement of the availability curve for a station.

# %%
avg_availability = bike_2019.groupby(['station_id'])['availability'].agg('mean')

# %%
len(avg_availability)
# Out:
# 572

# %%
bike_2019.groupby(['station_id'])['availability'].agg(['mean', 'max']).to_csv("average_availability_per_station.csv")

# %%
# Create a list of stations to delete (that have less than -10 availability on average)
avg_availability = avg_availability.reset_index()
del_list = avg_availability[avg_availability['availability'] < -10][['station_id', 'availability']]

# %%
# Drop rows that are in the delete list
bike_2019_2 = bike_2019[~bike_2019['station_id'].isin(del_list['station_id'])]

# %%
# Check that stations were dropped
len(bike_2019_2['station_id'].unique())
# Out:
# 545

# %% [markdown]
# ## Availability capping (lower, upper limit)

# %% [markdown]
# After removing stations having extreme negative outlying availability, we will be running the cumulative sum to calculate availability again, but this time with an upper (total capacity of a station) and lower limit (0).

# %%
grouped = bike_2019_2.groupby('station_id')

# %%
new_availability = []

# Lower limit is 0
lower = 0

# Initialize cumsum to 0
cumsum = 0

# Start with the first row
cur_station = 31000

for name, group in grouped:
    for row_index, row in group.iterrows():
        if row['station_id'] != cur_station:
            cur_station = row['station_id']
            cumsum = 0
        upper = row['capacity']
        cumsum += row['act']
        cumsum = max(min(cumsum, upper), lower)
        new_availability.append(cumsum)

# %%
bike_2019_2[['availability']] = new_availability

# %%
bike_2019_2.to_csv("bike_2019_transformed_new.csv", index=False)

# %% [markdown]
# ## Change availability to proportion value

# %%
bike_2019_2[['availability_p']] = round(bike_2019_2['availability'] / bike_2019_2['capacity'], 3)

# %%
bike_2019_2
# Out:
#          station_id                     station_name                 date  \
# 0             31000                STARTING BIKE NUM  2019-01-01 00:00:01
# 1             31000              Eads St & 15th St S  2019-01-02 09:46:15
# 2             31000              Eads St & 15th St S  2019-01-02 09:58:13
# 3             31000              Eads St & 15th St S  2019-01-02 12:09:20
# 4             31000              Eads St & 15th St S  2019-01-02 12:12:59
# ...             ...                              ...                  ...
# 7494715       32609  W Columbia St & N Washington St  2019-12-28 14:16:09
# 7494716       32609  W Columbia St & N Washington St  2019-12-28 14:16:24
# 7494717       32609  W Columbia St & N Washington St  2019-12-28 14:17:07
# 7494718       32609  W Columbia St & N Washington St  2019-12-28 14:17:08
# 7494719       32609  W Columbia St & N Washington St  2019-12-30 10:30:27
#
#           bike_id  act  reshuffle  availability  capacity  availability_p
# 0        starting    5          0           5.0      15.0           0.333
# 1          W23821   -1          0           4.0      15.0           0.267
# 2          W21229   -1          0           3.0      15.0           0.200
# 3          W23657    1          0           4.0      15.0           0.267
# 4          W23657   -1          0           3.0      15.0           0.200
# ...           ...  ...        ...           ...       ...             ...
# 7494715    W00632    1          0           4.0      12.0           0.333
# 7494716    W00420    1          0           5.0      12.0           0.417
# 7494717    W00632   -1          0           4.0      12.0           0.333
# 7494718    W00420   -1          0           3.0      12.0           0.250
# 7494719    W23434   -1          0           2.0      12.0           0.167
#
# [6857917 rows x 9 columns]

# %% [markdown]
# ## Add holidays

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar as calendar
cal = calendar()
holidays = cal.holidays(start=bike_2019_2['date'].min(), end=bike_2019_2['date'].max())
bike_2019_2['date_2'] = pd.to_datetime(bike_2019_2['date'], format='%Y-%m-%d').dt.date

# %%
bike_2019_2['is_holiday'] = bike_2019_2['date_2'].isin(holidays) * 1

# %%
bike_2019_2[bike_2019_2['is_holiday'] == 1]
# Out:
#          station_id                     station_name                 date  \
# 902           31000              Eads St & 15th St S  2019-05-27 11:27:21
# 903           31000              Eads St & 15th St S  2019-05-27 11:28:16
# 904           31000              Eads St & 15th St S  2019-05-27 12:11:17
# 905           31000              Eads St & 15th St S  2019-05-27 12:52:18
# 906           31000              Eads St & 15th St S  2019-05-27 13:25:14
# ...             ...                              ...                  ...
# 7493878       32609  W Columbia St & N Washington St  2019-05-27 17:52:55
# 7493879       32609  W Columbia St & N Washington St  2019-05-27 17:53:52
# 7494327       32609  W Columbia St & N Washington St  2019-09-02 08:47:04
# 7494328       32609  W Columbia St & N Washington St  2019-09-02 18:52:11
# 7494329       32609  W Columbia St & N Washington St  2019-09-02 18:53:06
#
#         bike_id  act  reshuffle  availability  capacity  availability_p  \
# 902      W24054   -1          0           4.0      15.0           0.267
# 903      W21241   -1          0           3.0      15.0           0.200
# 904      W00398    1          0           4.0      15.0           0.267
# 905      W00398   -1          0           3.0      15.0           0.200
# 906      W20162    1          0           4.0      15.0           0.267
# ...         ...  ...        ...           ...       ...             ...
# 7493878  W21119    1          0           7.0      12.0           0.583
# 7493879  W21119   -1          0           6.0      12.0           0.500
# 7494327  W22841   -1          0           9.0      12.0           0.750
# 7494328  W21779    1          0          10.0      12.0           0.833
# 7494329  W21779   -1          0           9.0      12.0           0.750
#
#              date_2  is_holiday
# 902      2019-05-27           1
# 903      2019-05-27           1
# 904      2019-05-27           1
# 905      2019-05-27           1
# 906      2019-05-27           1
# ...             ...         ...
# 7493878  2019-05-27           1
# 7493879  2019-05-27           1
# 7494327  2019-09-02           1
# 7494328  2019-09-02           1
# 7494329  2019-09-02           1
#
# [41269 rows x 11 columns]

# %% [markdown]
# ## Add is_weekend variable

# %%
bike_2019_2['is_weekend'] = ((pd.DatetimeIndex(bike_2019_2['date_2']).dayofweek) // 5 == 1).astype(int)

# %%
bike_2019_2[bike_2019_2['is_weekend'] == 1]
# Out:
#          station_id                     station_name                 date  \
# 13            31000              Eads St & 15th St S  2019-01-05 17:43:30
# 14            31000              Eads St & 15th St S  2019-01-06 13:29:17
# 15            31000              Eads St & 15th St S  2019-01-06 16:09:35
# 16            31000              Eads St & 15th St S  2019-01-06 16:10:08
# 17            31000              Eads St & 15th St S  2019-01-06 23:10:15
# ...             ...                              ...                  ...
# 7494714       32609  W Columbia St & N Washington St  2019-12-28 11:57:50
# 7494715       32609  W Columbia St & N Washington St  2019-12-28 14:16:09
# 7494716       32609  W Columbia St & N Washington St  2019-12-28 14:16:24
# 7494717       32609  W Columbia St & N Washington St  2019-12-28 14:17:07
# 7494718       32609  W Columbia St & N Washington St  2019-12-28 14:17:08
#
#         bike_id  act  reshuffle  availability  capacity  availability_p  \
# 13       W22916    1          0           2.0      15.0           0.133
# 14        65038    1          0           3.0      15.0           0.200
# 15       E00101    1          0           4.0      15.0           0.267
# 16        65038   -1          0           3.0      15.0           0.200
# 17       E00101   -1          0           2.0      15.0           0.133
# ...         ...  ...        ...           ...       ...             ...
# 7494714  W21270    1          0           3.0      12.0           0.250
# 7494715  W00632    1          0           4.0      12.0           0.333
# 7494716  W00420    1          0           5.0      12.0           0.417
# 7494717  W00632   -1          0           4.0      12.0           0.333
# 7494718  W00420   -1          0           3.0      12.0           0.250
#
#              date_2  is_holiday  is_weekend
# 13       2019-01-05           0           1
# 14       2019-01-06           0           1
# 15       2019-01-06           0           1
# 16       2019-01-06           0           1
# 17       2019-01-06           0           1
# ...             ...         ...         ...
# 7494714  2019-12-28           0           1
# 7494715  2019-12-28           0           1
# 7494716  2019-12-28           0           1
# 7494717  2019-12-28           0           1
# 7494718  2019-12-28           0           1
#
# [1799046 rows x 12 columns]

# %%
bike_2019_2 = bike_2019_2[['station_id', 'station_name', 'date', 'is_holiday', 'is_weekend', 'reshuffle', 'act', 'capacity', 'availability', 'availability_p']]

# %%
bike_2019_2.to_csv("bike_2019_transformed_new.csv", index=False)
