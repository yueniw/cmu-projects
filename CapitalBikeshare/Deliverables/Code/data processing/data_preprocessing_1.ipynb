# %%
import numpy as np
import pandas as pd
import janitor
import warnings
warnings.filterwarnings('ignore')
from datetime import datetime
import glob
import json
import requests

# %%
# Read all the month data for 2019
path = "/Users/lee14257/Development/CMU/Perspectives_in Data_Science/Project/2019"
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

bike2019 = pd.concat(li, axis=0, ignore_index=True)

# %%
len(bike2019)
# Out:
# 3398417

# %%
bike2019.head()
# Out:
#    Duration           Start date             End date  Start station number  \
# 0       429  2019-10-01 00:01:59  2019-10-01 00:09:08                 31214
# 1      1935  2019-10-01 00:03:07  2019-10-01 00:35:23                 31269
# 2       563  2019-10-01 00:03:51  2019-10-01 00:13:14                 31214
# 3       625  2019-10-01 00:05:34  2019-10-01 00:15:59                 31301
# 4       312  2019-10-01 00:05:47  2019-10-01 00:10:59                 31519
#
#                        Start station  End station number  \
# 0              17th & Corcoran St NW               31203
# 1       3rd St & Pennsylvania Ave SE               31269
# 2              17th & Corcoran St NW               31251
# 3  Ward Circle / American University               31317
# 4                      1st & O St NW               31109
#
#                      End station Bike number Member type
# 0     14th & Rhode Island Ave NW      W23731      Member
# 1   3rd St & Pennsylvania Ave SE      W22377      Member
# 2                 12th & L St NW      W23473      Member
# 3  Wisconsin Ave & Ingomar St NW      W21371      Member
# 4                  7th & T St NW      W23666      Member

# %%
bike2019['Start date'] = pd.to_datetime(bike2019['Start date'], utc=False)
bike2019['End date'] = pd.to_datetime(bike2019['End date'], utc=False)

# %%
# Number of unique stations
len(bike2019['End station number'].unique())
# Out:
# 581

# %% [markdown]
# ## Create Availability table

# %%
# Create Availability table
drop_df = bike2019[['Start station number', 'Start station', 'Start date', 'Bike number']].assign(act=-1)
drop_df.columns = ['station_id', 'station_name', 'date', 'bike_id', 'act']
pick_df = bike2019[['End station number', 'End station', 'End date', 'Bike number']].assign(act=1)
pick_df.columns = ['station_id', 'station_name', 'date', 'bike_id', 'act']
act_df = pd.concat([drop_df, pick_df])
act_df = act_df.assign(reshuffle=0)

# %%
act_df['station_id'].replace(0, 31127,inplace=True)
act_df = act_df.sort_values(['station_id', 'date'])

# %%
act_df
# Out:
#          station_id                     station_name                date  \
# 343942        31000              Eads St & 15th St S 2019-01-02 09:46:15
# 343993        31000              Eads St & 15th St S 2019-01-02 09:58:13
# 344460        31000              Eads St & 15th St S 2019-01-02 12:09:20
# 344552        31000              Eads St & 15th St S 2019-01-02 12:12:59
# 346772        31000              Eads St & 15th St S 2019-01-02 17:34:18
# ...             ...                              ...                 ...
# 2886440       32609  W Columbia St & N Washington St 2019-12-28 14:16:09
# 2886446       32609  W Columbia St & N Washington St 2019-12-28 14:16:24
# 2886696       32609  W Columbia St & N Washington St 2019-12-28 14:17:07
# 2886697       32609  W Columbia St & N Washington St 2019-12-28 14:17:08
# 2892805       32609  W Columbia St & N Washington St 2019-12-30 10:30:27
#
#         bike_id  act  reshuffle
# 343942   W23821   -1          0
# 343993   W21229   -1          0
# 344460   W23657    1          0
# 344552   W23657   -1          0
# 346772   W23821    1          0
# ...         ...  ...        ...
# 2886440  W00632    1          0
# 2886446  W00420    1          0
# 2886696  W00632   -1          0
# 2886697  W00420   -1          0
# 2892805  W23434   -1          0
#
# [6796834 rows x 6 columns]

# %%
# Testing cumsum to get availability
act_df_temp = act_df.assign(availability = act_df.groupby('station_id')['act'].transform(pd.Series.cumsum))

# %%
act_df_temp
# Out:
#          station_id                     station_name                date  \
# 343942        31000              Eads St & 15th St S 2019-01-02 09:46:15
# 343993        31000              Eads St & 15th St S 2019-01-02 09:58:13
# 344460        31000              Eads St & 15th St S 2019-01-02 12:09:20
# 344552        31000              Eads St & 15th St S 2019-01-02 12:12:59
# 346772        31000              Eads St & 15th St S 2019-01-02 17:34:18
# ...             ...                              ...                 ...
# 2886440       32609  W Columbia St & N Washington St 2019-12-28 14:16:09
# 2886446       32609  W Columbia St & N Washington St 2019-12-28 14:16:24
# 2886696       32609  W Columbia St & N Washington St 2019-12-28 14:17:07
# 2886697       32609  W Columbia St & N Washington St 2019-12-28 14:17:08
# 2892805       32609  W Columbia St & N Washington St 2019-12-30 10:30:27
#
#         bike_id  act  reshuffle  availability
# 343942   W23821   -1          0            -1
# 343993   W21229   -1          0            -2
# 344460   W23657    1          0            -1
# 344552   W23657   -1          0            -2
# 346772   W23821    1          0            -1
# ...         ...  ...        ...           ...
# 2886440  W00632    1          0            20
# 2886446  W00420    1          0            21
# 2886696  W00632   -1          0            20
# 2886697  W00420   -1          0            19
# 2892805  W23434   -1          0            18
#
# [6796834 rows x 7 columns]

# %% [markdown]
# ## Identify Reshuffled rows

# %%
# Add van reshuffled as additional rows
df_reshuffle = act_df.sort_values(['bike_id', 'date'])
df_reshuffle.head()
# Out:
#          station_id           station_name                date bike_id  act  \
# 1363967       31124    14th & Irving St NW 2019-11-21 08:47:33   21054   -1
# 1363967       31101         14th & V St NW 2019-11-21 08:54:07   21054    1
# 1364146       31101         14th & V St NW 2019-11-21 08:55:49   21054   -1
# 1364146       31214  17th & Corcoran St NW 2019-11-21 09:02:29   21054    1
# 1364411       31214  17th & Corcoran St NW 2019-11-21 09:12:15   21054   -1
#
#          reshuffle
# 1363967          0
# 1363967          0
# 1364146          0
# 1364146          0
# 1364411          0

# %%
# Shift previous stations to compare and determine reshuffled rows
df_reshuffle['station_id_prev'] = df_reshuffle['station_id'].shift()
df_reshuffle['station_name_prev'] = df_reshuffle['station_name'].shift()
df_reshuffle['bike_id_prev'] = df_reshuffle['bike_id'].shift()
df_reshuffle['date_prev'] = df_reshuffle['date'].shift()

# %%
df_reshuffle.head()
# Out:
#          station_id           station_name                date bike_id  act  \
# 1363967       31124    14th & Irving St NW 2019-11-21 08:47:33   21054   -1
# 1363967       31101         14th & V St NW 2019-11-21 08:54:07   21054    1
# 1364146       31101         14th & V St NW 2019-11-21 08:55:49   21054   -1
# 1364146       31214  17th & Corcoran St NW 2019-11-21 09:02:29   21054    1
# 1364411       31214  17th & Corcoran St NW 2019-11-21 09:12:15   21054   -1
#
#          reshuffle  station_id_prev      station_name_prev bike_id_prev  \
# 1363967          0              NaN                    NaN          NaN
# 1363967          0          31124.0    14th & Irving St NW        21054
# 1364146          0          31101.0         14th & V St NW        21054
# 1364146          0          31101.0         14th & V St NW        21054
# 1364411          0          31214.0  17th & Corcoran St NW        21054
#
#                   date_prev
# 1363967                 NaT
# 1363967 2019-11-21 08:47:33
# 1364146 2019-11-21 08:54:07
# 1364146 2019-11-21 08:55:49
# 1364411 2019-11-21 09:02:29

# %%
# Rows that need reshuffle (add rows)
need_reshuffle = df_reshuffle[(df_reshuffle['act'] == -1) & 
             (df_reshuffle['station_id'] != df_reshuffle['station_id_prev']) & 
             (df_reshuffle['bike_id'] == df_reshuffle['bike_id_prev'])]
need_reshuffle[['station_id_prev']] = need_reshuffle[['station_id_prev']].astype(int)
need_reshuffle.head()
# Out:
#          station_id                   station_name                date  \
# 1365289       31124            14th & Irving St NW 2019-11-21 11:42:54
# 1375451       31227      13th St & New York Ave NW 2019-11-22 16:42:55
# 1388885       31302   Wisconsin Ave & Newark St NW 2019-11-25 07:55:12
# 2761007       31299      Connecticut Ave & R St NW 2019-12-04 15:27:31
# 2764396       31242  18th St & Pennsylvania Ave NW 2019-12-04 22:09:07
#
#         bike_id  act  reshuffle  station_id_prev           station_name_prev  \
# 1365289   21054   -1          0            31227   13th St & New York Ave NW
# 1375451   21054   -1          0            31254              15th & K St NW
# 1388885   21054   -1          0            31246  M St & Pennsylvania Ave NW
# 2761007   21054   -1          0            31253              19th & K St NW
# 2764396   21054   -1          0            31203  14th & Rhode Island Ave NW
#
#         bike_id_prev           date_prev
# 1365289        21054 2019-11-21 09:21:34
# 1375451        21054 2019-11-22 08:54:57
# 1388885        21054 2019-11-23 17:21:11
# 2761007        21054 2019-12-03 08:12:44
# 2764396        21054 2019-12-04 15:37:13

# %%
# Add mid point dates for reshuffling vans
need_reshuffle['date_1q'] = need_reshuffle['date_prev'] + ((need_reshuffle['date'] - need_reshuffle['date_prev'])//3)
need_reshuffle['date_2q'] = need_reshuffle['date_prev'] + (2*(need_reshuffle['date'] - need_reshuffle['date_prev'])//3)
need_reshuffle['date_1q'] = need_reshuffle["date_1q"].dt.strftime("%Y-%m-%d %H:%M:%S")
need_reshuffle['date_2q'] = need_reshuffle["date_2q"].dt.strftime("%Y-%m-%d %H:%M:%S")
need_reshuffle.head()
# Out:
#          station_id                   station_name                date  \
# 1365289       31124            14th & Irving St NW 2019-11-21 11:42:54
# 1375451       31227      13th St & New York Ave NW 2019-11-22 16:42:55
# 1388885       31302   Wisconsin Ave & Newark St NW 2019-11-25 07:55:12
# 2761007       31299      Connecticut Ave & R St NW 2019-12-04 15:27:31
# 2764396       31242  18th St & Pennsylvania Ave NW 2019-12-04 22:09:07
#
#         bike_id  act  reshuffle  station_id_prev           station_name_prev  \
# 1365289   21054   -1          0            31227   13th St & New York Ave NW
# 1375451   21054   -1          0            31254              15th & K St NW
# 1388885   21054   -1          0            31246  M St & Pennsylvania Ave NW
# 2761007   21054   -1          0            31253              19th & K St NW
# 2764396   21054   -1          0            31203  14th & Rhode Island Ave NW
#
#         bike_id_prev           date_prev              date_1q  \
# 1365289        21054 2019-11-21 09:21:34  2019-11-21 10:08:40
# 1375451        21054 2019-11-22 08:54:57  2019-11-22 11:30:56
# 1388885        21054 2019-11-23 17:21:11  2019-11-24 06:12:31
# 2761007        21054 2019-12-03 08:12:44  2019-12-03 18:37:39
# 2764396        21054 2019-12-04 15:37:13  2019-12-04 17:47:51
#
#                      date_2q
# 1365289  2019-11-21 10:55:47
# 1375451  2019-11-22 14:06:55
# 1388885  2019-11-24 19:03:51
# 2761007  2019-12-04 05:02:35
# 2764396  2019-12-04 19:58:29

# %%
# Create Reshuffle rows
reshuffle_pick = need_reshuffle[['station_id_prev', 'station_name_prev', 'date_1q', 'bike_id_prev']].assign(act=-1)
reshuffle_pick.columns = ['station_id', 'station_name', 'date', 'bike_id', 'act']
reshuffle_drop = need_reshuffle[['station_id', 'station_name', 'date_2q', 'bike_id']].assign(act=1)
reshuffle_drop.columns = ['station_id', 'station_name', 'date', 'bike_id', 'act']
act_df_reshuffle = pd.concat([reshuffle_pick, reshuffle_drop])
act_df_reshuffle = act_df_reshuffle.assign(reshuffle=1)

# %%
act_df_reshuffle = act_df_reshuffle.sort_values(['bike_id', 'date'])

# %% [markdown]
# ## Combine original and reshuffle table together

# %%
# Add original and reshuffled table
act_df = act_df.reset_index(drop=True)
act_df_reshuffle = act_df_reshuffle.reset_index(drop=True)
final_act_df = pd.concat([act_df, act_df_reshuffle], ignore_index=True)
final_act_df.head()
# Out:
#    station_id         station_name                 date bike_id  act  \
# 0       31000  Eads St & 15th St S  2019-01-02 09:46:15  W23821   -1
# 1       31000  Eads St & 15th St S  2019-01-02 09:58:13  W21229   -1
# 2       31000  Eads St & 15th St S  2019-01-02 12:09:20  W23657    1
# 3       31000  Eads St & 15th St S  2019-01-02 12:12:59  W23657   -1
# 4       31000  Eads St & 15th St S  2019-01-02 17:34:18  W23821    1
#
#    reshuffle
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
# Change the "date" column to a datetime format
final_act_df['date'] =  pd.to_datetime(final_act_df['date'], format='%Y-%m-%d %H:%M:%S')

# %%
# Sort the dataframe by 'station_id', and 'date'
final_act_df = final_act_df.sort_values(['station_id', 'date'])
final_act_df.tail()
# Out:
#          station_id                     station_name                date  \
# 6796829       32609  W Columbia St & N Washington St 2019-12-28 14:16:09
# 6796830       32609  W Columbia St & N Washington St 2019-12-28 14:16:24
# 6796831       32609  W Columbia St & N Washington St 2019-12-28 14:17:07
# 6796832       32609  W Columbia St & N Washington St 2019-12-28 14:17:08
# 6796833       32609  W Columbia St & N Washington St 2019-12-30 10:30:27
#
#         bike_id  act  reshuffle
# 6796829  W00632    1          0
# 6796830  W00420    1          0
# 6796831  W00632   -1          0
# 6796832  W00420   -1          0
# 6796833  W23434   -1          0

# %%
# Number of unique station names
len(final_act_df['station_id'].unique())
# Out:
# 581

# %% [markdown]
# ## Adding starting bike number for each stations

# %%
# Load in the data for 2018 December
bike2018_dec = pd.read_csv("/Users/lee14257/Development/CMU/Perspectives_in Data_Science/Project/2018/201812-capitalbikeshare-tripdata.csv", index_col=None, header=0)

# %%
bike2018_dec.head()
# Out:
#    Duration           Start date             End date  Start station number  \
# 0       790  2018-12-01 00:00:44  2018-12-01 00:13:54                 31203
# 1       771  2018-12-01 00:00:55  2018-12-01 00:13:46                 31203
# 2       775  2018-12-01 00:00:55  2018-12-01 00:13:51                 31203
# 3       750  2018-12-01 00:01:08  2018-12-01 00:13:39                 31203
# 4       146  2018-12-01 00:02:45  2018-12-01 00:05:11                 31124
#
#                 Start station  End station number  \
# 0  14th & Rhode Island Ave NW               31116
# 1  14th & Rhode Island Ave NW               31116
# 2  14th & Rhode Island Ave NW               31116
# 3  14th & Rhode Island Ave NW               31116
# 4         14th & Irving St NW               31102
#
#                       End station Bike number Member type
# 0  California St & Florida Ave NW      W21477      Member
# 1  California St & Florida Ave NW      W22810      Member
# 2  California St & Florida Ave NW      W21144      Member
# 3  California St & Florida Ave NW      W23321      Member
# 4             11th & Kenyon St NW      W22304      Member

# %%
# Repeat preprocessing for 2018
bike2018_dec['Start date'] = pd.to_datetime(bike2018_dec['Start date'], utc=False)
bike2018_dec['End date'] = pd.to_datetime(bike2018_dec['End date'], utc=False)

# Create Availability table for 2018
drop_df2 = bike2018_dec[['Start station number', 'Start station', 'Start date', 'Bike number']].assign(act=-1)
drop_df2.columns = ['station_id', 'station_name', 'date', 'bike_id', 'act']
pick_df2 = bike2018_dec[['End station number', 'End station', 'End date', 'Bike number']].assign(act=1)
pick_df2.columns = ['station_id', 'station_name', 'date', 'bike_id', 'act']
act_df2 = pd.concat([drop_df2, pick_df2])
act_df2 = act_df2.assign(reshuffle=0)
act_df2 = act_df2.sort_values(['bike_id', 'date'])

# %%
act_df2.head()
# Out:
#        station_id                 station_name                date bike_id  \
# 137         31227    13th St & New York Ave NW 2018-12-01 01:33:45   23750
# 137         31019  Wilson Blvd & N Edgewood St 2018-12-01 02:50:50   23750
# 10853       31039    Wilson Blvd & N Quincy St 2018-12-03 11:32:14   23750
# 10853       31033    Barcroft Community Center 2018-12-03 11:49:20   23750
# 7281        31411    Georgia & Missouri Ave NW 2018-12-02 18:39:06   23751
#
#        act  reshuffle
# 137     -1          0
# 137      1          0
# 10853   -1          0
# 10853    1          0
# 7281    -1          0

# %%
# Shift the bike_id column up by 1
act_df2['bike_id_prev'] = act_df2['bike_id'].shift(-1)

# %%
# Get last trips for each bike_id (which station they arrived in last)
last_trips = act_df2.loc[(act_df2['bike_id'] != act_df2['bike_id_prev']) & (act_df2['act'] == 1)].drop(columns=['reshuffle', 'bike_id_prev'])

# %%
last_trips.head()
# Out:
#         station_id                 station_name                date bike_id  \
# 10853        31033    Barcroft Community Center 2018-12-03 11:49:20   23750
# 83797        31654    King Greenleaf Rec Center 2018-12-14 13:34:10   23751
# 43922        31628                1st & K St SE 2018-12-08 09:49:14   23757
# 152865       32026    Carroll & Ethan Allen Ave 2018-12-30 12:07:01   51020
# 156503       31096  S Walter Reed Dr & 8th St S 2018-12-31 02:30:34   51033
#
#         act
# 10853     1
# 83797     1
# 43922     1
# 152865    1
# 156503    1

# %%
# Sum all the bikes that landed in each station in 2018 December
starting_bike_num = last_trips.groupby('station_id')['act'].agg(['sum'])
starting_bike_num = starting_bike_num.rename(columns={"sum": "act"})

# %%
# Assign the date 2019-01-01 as the starting date
starting_bike_num = starting_bike_num.assign(station_name = 'STARTING BIKE NUM', date='2019-01-01 00:00:01', bike_id='starting', reshuffle=0)

# %%
# Change 'date' to a datetime type
starting_bike_num = starting_bike_num.reset_index()
starting_bike_num['date'] =  pd.to_datetime(starting_bike_num['date'])
starting_bike_num.head()
# Out:
#    station_id  act       station_name                date   bike_id  reshuffle
# 0       31000    5  STARTING BIKE NUM 2019-01-01 00:00:01  starting          0
# 1       31001    4  STARTING BIKE NUM 2019-01-01 00:00:01  starting          0
# 2       31002   16  STARTING BIKE NUM 2019-01-01 00:00:01  starting          0
# 3       31003    5  STARTING BIKE NUM 2019-01-01 00:00:01  starting          0
# 4       31004    7  STARTING BIKE NUM 2019-01-01 00:00:01  starting          0

# %%
# Total of 500 stations that have a starting bike number
len(starting_bike_num['station_id'].unique())
# Out:
# 500

# %%
# Add starting date to final df (concatenate as rows)
final_df_with_startdate = pd.concat([final_act_df, starting_bike_num], ignore_index=True)
final_df_with_startdate['station_id'].replace(0, 31127,inplace=True)

# %%
# Sort table by station id and date
final_df_with_startdate = final_df_with_startdate.sort_values(['station_id', 'date'])
final_df_with_startdate.head()
# Out:
#          station_id         station_name                date   bike_id  act  \
# 7494220       31000    STARTING BIKE NUM 2019-01-01 00:00:01  starting    5
# 0             31000  Eads St & 15th St S 2019-01-02 09:46:15    W23821   -1
# 1             31000  Eads St & 15th St S 2019-01-02 09:58:13    W21229   -1
# 2             31000  Eads St & 15th St S 2019-01-02 12:09:20    W23657    1
# 3             31000  Eads St & 15th St S 2019-01-02 12:12:59    W23657   -1
#
#          reshuffle
# 7494220          0
# 0                0
# 1                0
# 2                0
# 3                0

# %%
last_availability = final_df_with_startdate.groupby(['station_id'])['act'].agg(['sum'])
#last_availability.to_csv("last_availability.csv")

# %%
# Add availability column through cumsum
final_df_with_startdate = final_df_with_startdate.assign(availability = final_df_with_startdate.groupby('station_id')['act'].transform(pd.Series.cumsum))

# %%
# Resulting final table
final_df_with_startdate.head()
# Out:
#          station_id         station_name                date   bike_id  act  \
# 7494220       31000    STARTING BIKE NUM 2019-01-01 00:00:01  starting    5
# 0             31000  Eads St & 15th St S 2019-01-02 09:46:15    W23821   -1
# 1             31000  Eads St & 15th St S 2019-01-02 09:58:13    W21229   -1
# 2             31000  Eads St & 15th St S 2019-01-02 12:09:20    W23657    1
# 3             31000  Eads St & 15th St S 2019-01-02 12:12:59    W23657   -1
#
#          reshuffle  availability
# 7494220          0             5
# 0                0             4
# 1                0             3
# 2                0             4
# 3                0             3

# %% [markdown]
# ## Add bike tot_capacity column

# %%
# Get total capacity for each station using API
url_station_info = 'https://gbfs.capitalbikeshare.com/gbfs/en/station_information.json'
sta_info = pd.DataFrame(json.loads(requests.get(url_station_info).content)['data']['stations'])
sta_info.head()
# Out:
#                                            name station_type region_id  \
# 0                           Eads St & 15th St S      classic        41
# 1                        Crystal Dr & 20th St S      classic        41
# 2                        Crystal Dr & 15th St S      classic        41
# 3  Aurora Hills Cmty Ctr / 18th St & S Hayes St      classic        41
# 4    Pentagon City Metro / 12th St & S Hayes St      classic        41
#
#   short_name                                        rental_uris  capacity  \
# 0      31000  {'ios': 'https://dc.lft.to/lastmile_qr_scan', ...        15
# 1      31002  {'ios': 'https://dc.lft.to/lastmile_qr_scan', ...        17
# 2      31003  {'ios': 'https://dc.lft.to/lastmile_qr_scan', ...        16
# 3      31004  {'ios': 'https://dc.lft.to/lastmile_qr_scan', ...        12
# 4      31005  {'ios': 'https://dc.lft.to/lastmile_qr_scan', ...        18
#
#    eightd_has_key_dispenser  electric_bike_surcharge_waiver  \
# 0                     False                           False
# 1                     False                           False
# 2                     False                           False
# 3                     False                           False
# 4                     False                           False
#
#                             external_id  has_kiosk        lat  \
# 0  082469cc-1f3f-11e7-bf6b-3863bb334450       True  38.858971
# 1  08246c35-1f3f-11e7-bf6b-3863bb334450       True  38.856425
# 2  08246cd5-1f3f-11e7-bf6b-3863bb334450       True  38.861056
# 3  08246d68-1f3f-11e7-bf6b-3863bb334450       True  38.857866
# 4  08246df5-1f3f-11e7-bf6b-3863bb334450       True  38.862303
#
#       rental_methods        lon legacy_id station_id eightd_station_services
# 0  [KEY, CREDITCARD] -77.053230         1          1                      []
# 1  [KEY, CREDITCARD] -77.049232         3          3                      []
# 2  [KEY, CREDITCARD] -77.049417         4          4                      []
# 3  [KEY, CREDITCARD] -77.059490         5          5                      []
# 4  [KEY, CREDITCARD] -77.059936         6          6                      []

# %%
capacity = sta_info[['short_name', 'capacity', 'lon', 'lat']]
capacity = capacity.rename(columns={"short_name": "station_id"})
capacity['station_id'] = capacity['station_id'].astype(int)

# %%
#.to_csv("bike_capacity_lon_lat.csv", index=False)

# %%
capacity.head()
# Out:
#    station_id  capacity        lon        lat
# 0       31000        15 -77.053230  38.858971
# 1       31002        17 -77.049232  38.856425
# 2       31003        16 -77.049417  38.861056
# 3       31004        12 -77.059490  38.857866
# 4       31005        18 -77.059936  38.862303

# %%
final_act_df_cap = pd.merge(final_df_with_startdate, capacity[['station_id','capacity']],on='station_id', how='left')

# %%
final_act_df_cap
# Out:
#          station_id                     station_name                date  \
# 0             31000                STARTING BIKE NUM 2019-01-01 00:00:01
# 1             31000              Eads St & 15th St S 2019-01-02 09:46:15
# 2             31000              Eads St & 15th St S 2019-01-02 09:58:13
# 3             31000              Eads St & 15th St S 2019-01-02 12:09:20
# 4             31000              Eads St & 15th St S 2019-01-02 12:12:59
# ...             ...                              ...                 ...
# 7494715       32609  W Columbia St & N Washington St 2019-12-28 14:16:09
# 7494716       32609  W Columbia St & N Washington St 2019-12-28 14:16:24
# 7494717       32609  W Columbia St & N Washington St 2019-12-28 14:17:07
# 7494718       32609  W Columbia St & N Washington St 2019-12-28 14:17:08
# 7494719       32609  W Columbia St & N Washington St 2019-12-30 10:30:27
#
#           bike_id  act  reshuffle  availability  capacity
# 0        starting    5          0             5      15.0
# 1          W23821   -1          0             4      15.0
# 2          W21229   -1          0             3      15.0
# 3          W23657    1          0             4      15.0
# 4          W23657   -1          0             3      15.0
# ...           ...  ...        ...           ...       ...
# 7494715    W00632    1          0            -9      12.0
# 7494716    W00420    1          0            -8      12.0
# 7494717    W00632   -1          0            -9      12.0
# 7494718    W00420   -1          0           -10      12.0
# 7494719    W23434   -1          0           -11      12.0
#
# [7494720 rows x 8 columns]

# %%
# Output final table
final_act_df_cap.to_csv("bike2019_transformed.csv", index=False)
